# %% [markdown]
# # DeepANM: Getting Started
#
# Notebook này hướng dẫn sử dụng thư viện **DeepANM** theo phong cách người dùng cuối: load dữ liệu từ bộ dataset tích hợp và sử dụng các API cấp cao.
#
# ### Cài đặt:
# ```bash
# pip install git+https://github.com/manhthai1706/DeepANM.git
# ```

# %%
# !pip install git+https://github.com/manhthai1706/DeepANM.git

import deepanm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import QuantileTransformer

print(f"DeepANM version: {deepanm.__version__}")
# Out:
# Collecting git+https://github.com/manhthai1706/DeepANM.git
#   Cloning https://github.com/manhthai1706/DeepANM.git to /tmp/pip-req-build-w0nfbndx
#   Running command git clone --filter=blob:none --quiet https://github.com/manhthai1706/DeepANM.git /tmp/pip-req-build-w0nfbndx
#   Resolved https://github.com/manhthai1706/DeepANM.git to commit 76f600fde98326a46231b261c096b835ea2633bf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (2.9.0+cu128)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (1.6.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (3.10.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (1.16.3)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (8.4.2)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (0.13.2)
# Requirement already satisfied: requests>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from deepanm==1.0.0) (2.32.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->deepanm==1.0.0) (2.9.0.post0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->deepanm==1.0.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->deepanm==1.0.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->deepanm==1.0.0) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->deepanm==1.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->deepanm==1.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->deepanm==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->deepanm==1.0.0) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->deepanm==1.0.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->deepanm==1.0.0) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.12.0->deepanm==1.0.0) (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deepanm==1.0.0) (3.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.12.0->deepanm==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.12.0->deepanm==1.0.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->deepanm==1.0.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->deepanm==1.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->deepanm==1.0.0) (3.0.3)
# Building wheels for collected packages: deepanm
#   Building wheel for deepanm (pyproject.toml) ... done
#   Created wheel for deepanm: filename=deepanm-1.0.0-py3-none-any.whl size=22556 sha256=fd9677a2c750224ec1827b0b9d816d2d16e06e214f5569937d8b769024941614
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_cpw7dz2/wheels/56/bf/42/4aebf1f8d8a2a369f63f9a398031ee9b8f9e09b56a4abfc3de
# Successfully built deepanm
# Installing collected packages: deepanm
# Successfully installed deepanm-1.0.0
# DeepANM version: 1.0.0

# %% [markdown]
# ## 1. Load Dữ liệu từ thư viện
# Sử dụng module `deepanm.datasets` để lấy dữ liệu Sachs chính thức.

# %%
# Load dữ liệu protein signaling
data, headers = deepanm.datasets.load_sachs()

print(f"Dữ liệu có {data.shape[0]} mẫu và {data.shape[1]} biến.")
print(f"Các biến: {headers}")

# Tiền xử lý chuẩn hóa
qt = QuantileTransformer(output_distribution='normal', n_quantiles=500)
data_norm = qt.fit_transform(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2530951956.py in <cell line: 0>()
#       1 # Load dữ liệu protein signaling
# ----> 2 data, headers = deepanm.datasets.load_sachs()
#       3
#       4 print(f"Dữ liệu có {data.shape[0]} mẫu và {data.shape[1]} biến.")
#       5 print(f"Các biến: {headers}")
#
# AttributeError: module 'deepanm' has no attribute 'datasets'

# %% [markdown]
# ## 2. Khám phá nhân quả với DeepANM
# Chúng ta khởi tạo class chính `DeepANM`. Nếu truyền `data` vào ngay, mô hình sẽ tự động huấn luyện.

# %%
# Khởi tạo và huấn luyện tự động
model = deepanm.DeepANM(data=data_norm, epochs=200, lda=1.0)

# Trích xuất ma trận cạnh (Adjacency Matrix)
W_raw, W_bin = model.get_dag_matrix(threshold=0.15)

# %% [markdown]
# ## 3. Visualizing Causal Graph
# Xem đồ thị nhân quả mà mô hình đã học được.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(W_bin, annot=True, xticklabels=headers, yticklabels=headers, cmap="Greens")
plt.title("Mạng nhân quả Protein Signaling (Học bởi DeepANM)")
plt.show()

# %% [markdown]
# ## 4. Kiểm tra tính ổn định (Stability Check)
# Một tính năng của thư viện giúp kiểm tra xem các cơ chế nhân quả có đồng nhất trên toàn bộ tập dữ liệu không.

# %%
score, losses = model.check_stability(data_norm)
print(f"Stability Score: {score:.4f} (Càng thấp càng tốt)")
